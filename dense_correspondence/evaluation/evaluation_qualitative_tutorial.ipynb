# %% [markdown]
# ## Qualitative Evaluation Example

# %%
# %matplotlib inline

import random
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import torch
import dense_correspondence_manipulation.utils.utils as utils
utils.add_dense_correspondence_to_python_path()

import dense_correspondence
from dense_correspondence.evaluation.evaluation import *
import dense_correspondence.correspondence_tools.correspondence_plotter as correspondence_plotter
from dense_correspondence.dataset.dense_correspondence_dataset_masked import ImageType
# Out:
# /home/zhouxian/virtualenvs/pci_venv/local/lib/python2.7/site-packages/requests/__init__.py:83: RequestsDependencyWarning: Old version of cryptography ([1, 2, 3]) may cause slowdown.
#   warnings.warn(warning, RequestsDependencyWarning)

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %%
config_filename = os.path.join(utils.getDenseCorrespondenceSourceDir(), 'config', 
                               'dense_correspondence', 'evaluation', 'evaluation_test.yaml')
config = utils.getDictFromYamlFilename(config_filename)
default_config = utils.get_defaults_config()

# utils.set_cuda_visible_devices([0])
dce = DenseCorrespondenceEvaluation(config)
DCE = DenseCorrespondenceEvaluation

network_name = "duck_3"
dcn = dce.load_network_from_config(network_name)
dataset = dcn.load_training_dataset()
DenseCorrespondenceEvaluation.evaluate_network_qualitative(dcn, dataset=dataset, randomize=True)
# Out:
# /home/zhouxian/virtualenvs/pci_venv/local/lib/python2.7/site-packages/torch/nn/modules/module.py:482: UserWarning: src is not broadcastable to dst, but they have the same number of elements.  Falling back to deprecated pointwise behavior.
#   own_state[name].copy_(param)
# Using SpartanDataset:
#    - in train mode
#    - number of scenes 3
#    - total images:     1296
#
#
# -----------Train Data Evaluation----------------
# Image pair (252, 297)
# /home/zhouxian/virtualenvs/pci_venv/local/lib/python2.7/site-packages/torch/nn/functional.py:1423: UserWarning: nn.functional.upsample_bilinear is deprecated. Use nn.functional.upsample instead.
#   warnings.warn("nn.functional.upsample_bilinear is deprecated. Use nn.functional.upsample instead.")
# Could not find descriptor image stats...
# Only normalizing pairs of images!
# Image pair (54, 15)
# Could not find descriptor image stats...
# Only normalizing pairs of images!
# Image pair (386, 55)
# Could not find descriptor image stats...
# Only normalizing pairs of images!
# Image pair (424, 321)
# Could not find descriptor image stats...
# Only normalizing pairs of images!
# Image pair (250, 163)
# Could not find descriptor image stats...
# Only normalizing pairs of images!
# -----------Test Data Evaluation----------------
# Image pair (63, 336)
# Could not find descriptor image stats...
# Only normalizing pairs of images!
# Image pair (113, 107)
# Could not find descriptor image stats...
# Only normalizing pairs of images!
# Image pair (254, 278)
# Could not find descriptor image stats...
# Only normalizing pairs of images!
# Image pair (27, 164)
# Could not find descriptor image stats...
# Only normalizing pairs of images!
# Image pair (99, 266)
# Could not find descriptor image stats...
# Only normalizing pairs of images!
